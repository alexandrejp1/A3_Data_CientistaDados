# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ocorrencia=pd.read_csv('ocorrencia.csv', sep = ';')
ocorrencia
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  52242               52242                INCIDENTE
# ...

# %%
ocorrencias_filtradas = ocorrencia.loc[:,['codigo_ocorrencia1', 'ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_uf', 'ocorrencia_aerodromo', 'ocorrencia_dia', 'ocorrencia_hora']]
ocorrencias_filtradas[['Dia','Mes', 'Ano']] = ocorrencias_filtradas.ocorrencia_dia.str.split("/",expand=True,)
ocorrencias_filtradas
# Out:
#       codigo_ocorrencia1 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora Dia  \
# ...

# %%
aeronaves
